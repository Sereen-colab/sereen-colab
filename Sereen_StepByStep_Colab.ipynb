# %% [markdown]
# # Sereen Face-Locked Colab
# This notebook sets up Stable Diffusion with face locking (ReActor).

# %%
# !apt -y update -qq
# !apt -y install -qq aria2
# !pip install -q torch torchvision torchaudio xformers
# !pip install -q git+https://github.com/camenduru/stable-diffusion-webui-colab

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd stable-diffusion-webui
# !git clone https://github.com/Gourieff/sd-webui-reactor extensions/sd-webui-reactor

# %%
# !COMMANDLINE_ARGS='--share --disable-safe-unpickle --xformers' REQS_FILE=requirements.txt python launch.py
